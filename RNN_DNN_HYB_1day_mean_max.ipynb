# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
# %matplotlib inline

# %% [markdown]
# # Data preprocessing
# ## Data preparation:
# * Fix NA values
# * Parse date-time into pandas dataframe index
# * Specified clear names for each columns

# %%
def parse(x):
	return datetime.strptime(x, '%Y %m %d %H')

# %%
temp = pd.read_csv('data_hrly.csv')

# %%
dataset = pd.read_csv('data_hrly.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
dataset.drop('No', axis=1, inplace=True)
dataset.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
dataset.index.name = 'date'

pol_avg=dataset['pollution'].mean()
pol_std=dataset['pollution'].std()
low=int(pol_avg-pol_std/2)
high=int(pol_avg+pol_std/2)
dataset['pollution']=dataset['pollution'].apply(lambda x: np.random.choice([x for x in range(low,high)]) if (np.isnan(x)) else x)

# %%
dataset['month'] = np.array(temp['month'])
print("** DATA PROCESSING COMPLETED **")
dataset.to_csv('pollution.csv')
# Out:
# ** DATA PROCESSING COMPLETED **

# %% [markdown]
# # Importing and visualizing the data

# %%
dataset = pd.read_csv('pollution.csv',index_col='date')
fig=plt.figure(figsize=(20, 3), dpi= 80, facecolor='w', edgecolor='k')
dataset['pollution'][:365*24].plot()
plt.title('Pollution Trend of 1 Year')
plt.xlabel('Time')
plt.ylabel('Pollution (pm 2.5)')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
#Label Encoder
lbe = LabelEncoder()
#One hot encoder for the wind direction
ohe = OneHotEncoder(categorical_features=[4])
ohe_month = OneHotEncoder(categorical_features=[10])
pol_scaler = MinMaxScaler()
wea_scaler = MinMaxScaler()

# %%
dataset = pd.read_csv('pollution.csv',index_col='date')
dataset['wnd_dir'] = lbe.fit_transform(dataset['wnd_dir'])
dataset= pd.DataFrame(ohe.fit_transform(dataset).toarray()[:,1:])
dataset = ohe_month.fit_transform(dataset).toarray()
dataset = pd.DataFrame(dataset[:,1:])
pollution_data=np.array(dataset.iloc[:,14])
weather_data=np.array(dataset.drop(14,axis=1))
pollution_data =pol_scaler.fit_transform(pollution_data.reshape(-1,1))
#Creating the dataset for DNN
weather_data = wea_scaler.fit_transform(weather_data)
print("Shape: ",weather_data.shape)
# Out:
# Shape:  (43824, 20)
# /usr/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:390: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# /usr/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:390: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %% [markdown]
# # Splitting the data into train and test set

# %%
#FOR RNN DATA
cut=24*(28000//24)
training_set_rnn = pollution_data[:cut,:].reshape(-1,24,1)
training_set_dnn = weather_data[:cut,:].reshape(-1,24,20)
test_set_rnn = pollution_data[cut:,:].reshape(-1,24,1)
test_set_dnn = weather_data[cut:,:].reshape(-1,24,20)

tr_rnn=[]
tr_dnn=[]
for day,ddy in zip(training_set_rnn,training_set_dnn):
    mx=day.argmax()
    tr_rnn.append(day[mx])
    tr_dnn.append(ddy.mean(axis=0))

training_set_rnn=np.array(tr_rnn)
training_set_dnn=np.array(tr_dnn)

tst_rnn=[]
tst_dnn=[]
for day,ddy in zip(test_set_rnn,test_set_dnn):
    mx=day.argmax()
    tst_rnn.append(day[mx])
    tst_dnn.append(ddy.mean(axis=0))

test_set_rnn=np.array(tst_rnn)
test_set_dnn=np.array(tst_dnn)

# %%
training_set_rnn.shape, training_set_dnn.shape, test_set_rnn.shape, test_set_dnn.shape
# Out:
# ((1583, 1), (1583, 20), (243, 1), (243, 20))

# %%
PRED_DIST=1

# %%
def next_batch(training_data_rnn,training_data_dnn,steps):
    """
    INPUT: Data(For RNN and DNN), Time Steps per batch
    OUTPUT: Input batch for RNN and DNN at 't' and Output data (pollution) at 't+1'
    """
    
    # Randomly initializing the start point
    pred_dist=PRED_DIST
    ts_start = np.random.randint(low = 0, high = len(training_data_rnn)-steps-pred_dist)
    # the random start to random start + steps + 1. Then reshape this data to be (1,steps+1)
    x_batch_rnn = training_data_rnn[ts_start: ts_start + steps]                  #(steps,1)
    x_batch_dnn = training_data_dnn[ts_start+pred_dist: ts_start+pred_dist+ steps]  #(steps,20)
    y_out = training_data_rnn[ts_start+pred_dist: ts_start+pred_dist+ steps]  #(steps,1)
    # Values for RNN reshaped to (-1,steps,1)
    #               0 to t                        ,             0 to t       ,1 to t+1 (pred_dist to pred_dist+1)    
    return x_batch_rnn.reshape(-1,steps,1) , x_batch_dnn.reshape(steps,-1), y_out.reshape(steps,1)

# %%
import os
#Setting up tensorflow on GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import tensorflow as tf
from nn_function import *

# %%
#Reseting the default global graph
tf.reset_default_graph()

# %% [markdown]
# # Creating the neural network

# %%
#Declarying the constants
NUMBER_NEU = 128
N_IP = 1
N_OP = 1
STEPS = 60
LR = 0.0001
#For 40k iterations
ITER = 40000
#Output neurons for the LSTM and DNN layers
N_OUT =128

# %%
#Placeholders for input batches
x_rnn = tf.placeholder(dtype=tf.float32,shape=(None,None,N_IP))
x_dnn = tf.placeholder(dtype=tf.float32,shape=(None,20))
#Placeholders for output batches
y= tf.placeholder(dtype=tf.float32,shape=(None,N_OP))
#For dropout layers
hold_proba = tf.placeholder(dtype=tf.float32)

# %%
#Making the LSTM cell
cell = dropout_wrapper(hold_proba,create_LSTM_cell(NUMBER_NEU))
# Out:
# WARNING:tensorflow:From /home/archer/machine_learning/ntt_pollution/nn_function.py:50: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').

# %%
#RNN output
output , states = create_RNN(cell,x_rnn)
#Selecting the final output form the layer
rnn_output = output[-1]
#Connecting the output to a DNN layer
lstm_fc_out = dnn_layer(rnn_output,N_OUT,name="LSTM_op")
lstm_fc_drop = tf.nn.dropout(lstm_fc_out, hold_proba,name="drop0")

# %%
#Making the dnn layers with the DNN data
dnn_op = dnn_layer(x_dnn,N_OUT)

# %%
#Connecting/Concatenating the DNN and RNN layers
connected_layer = tf.concat([dnn_op, lstm_fc_drop], axis=1,name="connected")
dropout_layer = tf.nn.dropout(connected_layer,hold_proba,name="drop1")
#Adding another DNN+dropout layer with relu activation
connected_layer2 = tf.nn.relu(dnn_layer(dropout_layer,size=1024),name="dnn1")
dropout_layer2 = tf.nn.dropout(connected_layer2,hold_proba,name="drop2")

# %%
#Calculating the final output node with Sigmoid activation
network_op = tf.sigmoid(dnn_layer(dropout_layer2,1),name="network_op")

# %%
#Creating the MAE loss function
loss = tf.losses.huber_loss(labels=network_op,predictions=y)
#Creating the optimizer and trainer
optim = tf.train.AdamOptimizer(learning_rate=LR)
train = optim.minimize(loss)

# %%
#Creating the varaible initializer and saver
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
with tf.Session() as sess:
    sess.run(init)
    for i in range(ITER):
        x_rnn_batch,x_dnn_batch,y_batch = next_batch(training_set_rnn,training_set_dnn,steps=STEPS)
        sess.run(train,feed_dict = {x_rnn:x_rnn_batch,x_dnn:x_dnn_batch ,y: y_batch , hold_proba:0.8})
        if i % 100 == 0:
            x_rnn_test,x_dnn_test,y_test = next_batch(test_set_rnn,test_set_dnn,steps=7)
            print("At step",i,"\t\tMean Absolute Error (Train): %1.5f"%(sess.run(loss,feed_dict = {x_rnn:x_rnn_batch,x_dnn:x_dnn_batch ,y: y_batch , hold_proba:1.0})),"\t\tMean Absolute Error (Test): %1.5f"%(sess.run(loss,feed_dict = {x_rnn:x_rnn_test,x_dnn:x_dnn_test ,y: y_test , hold_proba:1.0})))
    saver.save(sess, "Pollution_model/model")
# Out:
# At step 0 		Mean Absolute Error (Train): 0.02168 		Mean Absolute Error (Test): 0.03049
# At step 100 		Mean Absolute Error (Train): 0.00318 		Mean Absolute Error (Test): 0.00264
# At step 200 		Mean Absolute Error (Train): 0.00682 		Mean Absolute Error (Test): 0.00876
# At step 300 		Mean Absolute Error (Train): 0.00653 		Mean Absolute Error (Test): 0.00125
# At step 400 		Mean Absolute Error (Train): 0.00707 		Mean Absolute Error (Test): 0.00580
# At step 500 		Mean Absolute Error (Train): 0.00135 		Mean Absolute Error (Test): 0.01026
# At step 600 		Mean Absolute Error (Train): 0.00184 		Mean Absolute Error (Test): 0.00255
# At step 700 		Mean Absolute Error (Train): 0.00336 		Mean Absolute Error (Test): 0.00829
# At step 800 		Mean Absolute Error (Train): 0.00775 		Mean Absolute Error (Test): 0.00246
# At step 900 		Mean Absolute Error (Train): 0.00254 		Mean Absolute Error (Test): 0.00729
# At step 1000 		Mean Absolute Error (Train): 0.00469 		Mean Absolute Error (Test): 0.00327
# At step 1100 		Mean Absolute Error (Train): 0.01009 		Mean Absolute Error (Test): 0.00082
# At step 1200 		Mean Absolute Error (Train): 0.01246 		Mean Absolute Error (Test): 0.00609
# At step 1300 		Mean Absolute Error (Train): 0.00189 		Mean Absolute Error (Test): 0.00126
# At step 1400 		Mean Absolute Error (Train): 0.00626 		Mean Absolute Error (Test): 0.00322
# At step 1500 		Mean Absolute Error (Train): 0.00243 		Mean Absolute Error (Test): 0.00735
# At step 1600 		Mean Absolute Error (Train): 0.00461 		Mean Absolute Error (Test): 0.00558
# At step 1700 		Mean Absolute Error (Train): 0.00420 		Mean Absolute Error (Test): 0.00351
# At step 1800 		Mean Absolute Error (Train): 0.00281 		Mean Absolute Error (Test): 0.00343
# At step 1900 		Mean Absolute Error (Train): 0.00389 		Mean Absolute Error (Test): 0.00622
# At step 2000 		Mean Absolute Error (Train): 0.00127 		Mean Absolute Error (Test): 0.00890
# At step 2100 		Mean Absolute Error (Train): 0.00158 		Mean Absolute Error (Test): 0.00250
# At step 2200 		Mean Absolute Error (Train): 0.00265 		Mean Absolute Error (Test): 0.00280
# At step 2300 		Mean Absolute Error (Train): 0.00280 		Mean Absolute Error (Test): 0.00553
# At step 2400 		Mean Absolute Error (Train): 0.00167 		Mean Absolute Error (Test): 0.00107
# At step 2500 		Mean Absolute Error (Train): 0.00353 		Mean Absolute Error (Test): 0.00589
# At step 2600 		Mean Absolute Error (Train): 0.00243 		Mean Absolute Error (Test): 0.00772
# At step 2700 		Mean Absolute Error (Train): 0.00410 		Mean Absolute Error (Test): 0.00623
# At step 2800 		Mean Absolute Error (Train): 0.00138 		Mean Absolute Error (Test): 0.00653
# At step 2900 		Mean Absolute Error (Train): 0.00168 		Mean Absolute Error (Test): 0.00275
# At step 3000 		Mean Absolute Error (Train): 0.00214 		Mean Absolute Error (Test): 0.00709
# At step 3100 		Mean Absolute Error (Train): 0.00163 		Mean Absolute Error (Test): 0.00386
# At step 3200 		Mean Absolute Error (Train): 0.00321 		Mean Absolute Error (Test): 0.00304
# At step 3300 		Mean Absolute Error (Train): 0.00107 		Mean Absolute Error (Test): 0.00302
# At step 3400 		Mean Absolute Error (Train): 0.00408 		Mean Absolute Error (Test): 0.00289
# At step 3500 		Mean Absolute Error (Train): 0.00306 		Mean Absolute Error (Test): 0.00234
# At step 3600 		Mean Absolute Error (Train): 0.01146 		Mean Absolute Error (Test): 0.00459
# At step 3700 		Mean Absolute Error (Train): 0.00638 		Mean Absolute Error (Test): 0.00332
# At step 3800 		Mean Absolute Error (Train): 0.01424 		Mean Absolute Error (Test): 0.00083
# At step 3900 		Mean Absolute Error (Train): 0.00150 		Mean Absolute Error (Test): 0.00440
# At step 4000 		Mean Absolute Error (Train): 0.00243 		Mean Absolute Error (Test): 0.00317
# At step 4100 		Mean Absolute Error (Train): 0.00243 		Mean Absolute Error (Test): 0.00105
# At step 4200 		Mean Absolute Error (Train): 0.00175 		Mean Absolute Error (Test): 0.00144
# At step 4300 		Mean Absolute Error (Train): 0.00163 		Mean Absolute Error (Test): 0.00450
# At step 4400 		Mean Absolute Error (Train): 0.00670 		Mean Absolute Error (Test): 0.00389
# At step 4500 		Mean Absolute Error (Train): 0.00247 		Mean Absolute Error (Test): 0.00074
# At step 4600 		Mean Absolute Error (Train): 0.00103 		Mean Absolute Error (Test): 0.00086
# At step 4700 		Mean Absolute Error (Train): 0.00240 		Mean Absolute Error (Test): 0.00190
# At step 4800 		Mean Absolute Error (Train): 0.00220 		Mean Absolute Error (Test): 0.00068
# At step 4900 		Mean Absolute Error (Train): 0.00987 		Mean Absolute Error (Test): 0.00190
# At step 5000 		Mean Absolute Error (Train): 0.00485 		Mean Absolute Error (Test): 0.00083
# At step 5100 		Mean Absolute Error (Train): 0.00156 		Mean Absolute Error (Test): 0.00215
# At step 5200 		Mean Absolute Error (Train): 0.01022 		Mean Absolute Error (Test): 0.00328
# At step 5300 		Mean Absolute Error (Train): 0.00235 		Mean Absolute Error (Test): 0.00262
# At step 5400 		Mean Absolute Error (Train): 0.00329 		Mean Absolute Error (Test): 0.00211
# At step 5500 		Mean Absolute Error (Train): 0.00178 		Mean Absolute Error (Test): 0.00399
# At step 5600 		Mean Absolute Error (Train): 0.00632 		Mean Absolute Error (Test): 0.00368
# At step 5700 		Mean Absolute Error (Train): 0.00931 		Mean Absolute Error (Test): 0.00071
# At step 5800 		Mean Absolute Error (Train): 0.00248 		Mean Absolute Error (Test): 0.00355
# At step 5900 		Mean Absolute Error (Train): 0.00396 		Mean Absolute Error (Test): 0.00281
# At step 6000 		Mean Absolute Error (Train): 0.00256 		Mean Absolute Error (Test): 0.00131
# At step 6100 		Mean Absolute Error (Train): 0.00174 		Mean Absolute Error (Test): 0.00318
# At step 6200 		Mean Absolute Error (Train): 0.00731 		Mean Absolute Error (Test): 0.00432
# At step 6300 		Mean Absolute Error (Train): 0.00468 		Mean Absolute Error (Test): 0.00315
# At step 6400 		Mean Absolute Error (Train): 0.00162 		Mean Absolute Error (Test): 0.00070
# At step 6500 		Mean Absolute Error (Train): 0.00451 		Mean Absolute Error (Test): 0.00105
# At step 6600 		Mean Absolute Error (Train): 0.00127 		Mean Absolute Error (Test): 0.00069
# At step 6700 		Mean Absolute Error (Train): 0.00183 		Mean Absolute Error (Test): 0.00080
# At step 6800 		Mean Absolute Error (Train): 0.01153 		Mean Absolute Error (Test): 0.00108
# At step 6900 		Mean Absolute Error (Train): 0.00252 		Mean Absolute Error (Test): 0.00264
# At step 7000 		Mean Absolute Error (Train): 0.00254 		Mean Absolute Error (Test): 0.00071
# At step 7100 		Mean Absolute Error (Train): 0.00386 		Mean Absolute Error (Test): 0.00079
# At step 7200 		Mean Absolute Error (Train): 0.00104 		Mean Absolute Error (Test): 0.00367
# At step 7300 		Mean Absolute Error (Train): 0.00106 		Mean Absolute Error (Test): 0.01010
# At step 7400 		Mean Absolute Error (Train): 0.00135 		Mean Absolute Error (Test): 0.00252
# At step 7500 		Mean Absolute Error (Train): 0.00181 		Mean Absolute Error (Test): 0.00510
# At step 7600 		Mean Absolute Error (Train): 0.00179 		Mean Absolute Error (Test): 0.00387
# At step 7700 		Mean Absolute Error (Train): 0.00986 		Mean Absolute Error (Test): 0.00199
# At step 7800 		Mean Absolute Error (Train): 0.00186 		Mean Absolute Error (Test): 0.00179
# At step 7900 		Mean Absolute Error (Train): 0.00265 		Mean Absolute Error (Test): 0.00344
# At step 8000 		Mean Absolute Error (Train): 0.00379 		Mean Absolute Error (Test): 0.00556
# At step 8100 		Mean Absolute Error (Train): 0.00292 		Mean Absolute Error (Test): 0.00321
# At step 8200 		Mean Absolute Error (Train): 0.00356 		Mean Absolute Error (Test): 0.00060
# At step 8300 		Mean Absolute Error (Train): 0.00145 		Mean Absolute Error (Test): 0.00535
# At step 8400 		Mean Absolute Error (Train): 0.00271 		Mean Absolute Error (Test): 0.00327
# At step 8500 		Mean Absolute Error (Train): 0.00186 		Mean Absolute Error (Test): 0.00307
# At step 8600 		Mean Absolute Error (Train): 0.00334 		Mean Absolute Error (Test): 0.00592
# At step 8700 		Mean Absolute Error (Train): 0.00092 		Mean Absolute Error (Test): 0.00248
# At step 8800 		Mean Absolute Error (Train): 0.00217 		Mean Absolute Error (Test): 0.00135
# At step 8900 		Mean Absolute Error (Train): 0.00221 		Mean Absolute Error (Test): 0.00503
# At step 9000 		Mean Absolute Error (Train): 0.00273 		Mean Absolute Error (Test): 0.00544
# At step 9100 		Mean Absolute Error (Train): 0.00656 		Mean Absolute Error (Test): 0.00085
# At step 9200 		Mean Absolute Error (Train): 0.00361 		Mean Absolute Error (Test): 0.00188
# At step 9300 		Mean Absolute Error (Train): 0.00280 		Mean Absolute Error (Test): 0.00080
# At step 9400 		Mean Absolute Error (Train): 0.00136 		Mean Absolute Error (Test): 0.00961
# At step 9500 		Mean Absolute Error (Train): 0.00265 		Mean Absolute Error (Test): 0.00399
# At step 9600 		Mean Absolute Error (Train): 0.00134 		Mean Absolute Error (Test): 0.00502
# At step 9700 		Mean Absolute Error (Train): 0.00266 		Mean Absolute Error (Test): 0.00243
# At step 9800 		Mean Absolute Error (Train): 0.00156 		Mean Absolute Error (Test): 0.00368
# At step 9900 		Mean Absolute Error (Train): 0.00351 		Mean Absolute Error (Test): 0.00626
# At step 10000 		Mean Absolute Error (Train): 0.00185 		Mean Absolute Error (Test): 0.00527
# At step 10100 		Mean Absolute Error (Train): 0.00219 		Mean Absolute Error (Test): 0.00240
# At step 10200 		Mean Absolute Error (Train): 0.00347 		Mean Absolute Error (Test): 0.00650
# At step 10300 		Mean Absolute Error (Train): 0.00140 		Mean Absolute Error (Test): 0.00519
# At step 10400 		Mean Absolute Error (Train): 0.00230 		Mean Absolute Error (Test): 0.00378
# At step 10500 		Mean Absolute Error (Train): 0.00484 		Mean Absolute Error (Test): 0.00363
# At step 10600 		Mean Absolute Error (Train): 0.00119 		Mean Absolute Error (Test): 0.00093
# At step 10700 		Mean Absolute Error (Train): 0.00183 		Mean Absolute Error (Test): 0.00499
# At step 10800 		Mean Absolute Error (Train): 0.00733 		Mean Absolute Error (Test): 0.00066
# At step 10900 		Mean Absolute Error (Train): 0.00138 		Mean Absolute Error (Test): 0.00318
# At step 11000 		Mean Absolute Error (Train): 0.00165 		Mean Absolute Error (Test): 0.00410
# At step 11100 		Mean Absolute Error (Train): 0.00132 		Mean Absolute Error (Test): 0.00472
# At step 11200 		Mean Absolute Error (Train): 0.00142 		Mean Absolute Error (Test): 0.00238
# At step 11300 		Mean Absolute Error (Train): 0.00144 		Mean Absolute Error (Test): 0.00253
# At step 11400 		Mean Absolute Error (Train): 0.00214 		Mean Absolute Error (Test): 0.00634
# At step 11500 		Mean Absolute Error (Train): 0.00292 		Mean Absolute Error (Test): 0.00646
# At step 11600 		Mean Absolute Error (Train): 0.00091 		Mean Absolute Error (Test): 0.00083
# At step 11700 		Mean Absolute Error (Train): 0.00238 		Mean Absolute Error (Test): 0.00278
# At step 11800 		Mean Absolute Error (Train): 0.00226 		Mean Absolute Error (Test): 0.00303
# At step 11900 		Mean Absolute Error (Train): 0.00828 		Mean Absolute Error (Test): 0.00424
# At step 12000 		Mean Absolute Error (Train): 0.00136 		Mean Absolute Error (Test): 0.00447
# At step 12100 		Mean Absolute Error (Train): 0.00438 		Mean Absolute Error (Test): 0.00393
# At step 12200 		Mean Absolute Error (Train): 0.00281 		Mean Absolute Error (Test): 0.00302
# At step 12300 		Mean Absolute Error (Train): 0.00136 		Mean Absolute Error (Test): 0.00426
# At step 12400 		Mean Absolute Error (Train): 0.00125 		Mean Absolute Error (Test): 0.00494
# At step 12500 		Mean Absolute Error (Train): 0.00216 		Mean Absolute Error (Test): 0.00154
# At step 12600 		Mean Absolute Error (Train): 0.00181 		Mean Absolute Error (Test): 0.00456
# At step 12700 		Mean Absolute Error (Train): 0.00585 		Mean Absolute Error (Test): 0.00392
# At step 12800 		Mean Absolute Error (Train): 0.00270 		Mean Absolute Error (Test): 0.00315
# At step 12900 		Mean Absolute Error (Train): 0.00205 		Mean Absolute Error (Test): 0.00329
# At step 13000 		Mean Absolute Error (Train): 0.00133 		Mean Absolute Error (Test): 0.00405
# At step 13100 		Mean Absolute Error (Train): 0.00616 		Mean Absolute Error (Test): 0.00204
# At step 13200 		Mean Absolute Error (Train): 0.00148 		Mean Absolute Error (Test): 0.00321
# At step 13300 		Mean Absolute Error (Train): 0.00163 		Mean Absolute Error (Test): 0.00489
# At step 13400 		Mean Absolute Error (Train): 0.00158 		Mean Absolute Error (Test): 0.00214
# At step 13500 		Mean Absolute Error (Train): 0.00687 		Mean Absolute Error (Test): 0.01103
# At step 13600 		Mean Absolute Error (Train): 0.00311 		Mean Absolute Error (Test): 0.00138
# At step 13700 		Mean Absolute Error (Train): 0.00350 		Mean Absolute Error (Test): 0.00242
# At step 13800 		Mean Absolute Error (Train): 0.00633 		Mean Absolute Error (Test): 0.00396
# At step 13900 		Mean Absolute Error (Train): 0.00123 		Mean Absolute Error (Test): 0.00199
# At step 14000 		Mean Absolute Error (Train): 0.00174 		Mean Absolute Error (Test): 0.00065
# At step 14100 		Mean Absolute Error (Train): 0.00150 		Mean Absolute Error (Test): 0.00492
# At step 14200 		Mean Absolute Error (Train): 0.00666 		Mean Absolute Error (Test): 0.00466
# At step 14300 		Mean Absolute Error (Train): 0.00196 		Mean Absolute Error (Test): 0.00572
# At step 14400 		Mean Absolute Error (Train): 0.00104 		Mean Absolute Error (Test): 0.00670
# At step 14500 		Mean Absolute Error (Train): 0.00147 		Mean Absolute Error (Test): 0.00343
# At step 14600 		Mean Absolute Error (Train): 0.00150 		Mean Absolute Error (Test): 0.00378
# At step 14700 		Mean Absolute Error (Train): 0.00288 		Mean Absolute Error (Test): 0.00192
# At step 14800 		Mean Absolute Error (Train): 0.00142 		Mean Absolute Error (Test): 0.00099
# At step 14900 		Mean Absolute Error (Train): 0.00173 		Mean Absolute Error (Test): 0.00482
# At step 15000 		Mean Absolute Error (Train): 0.00284 		Mean Absolute Error (Test): 0.00392
# At step 15100 		Mean Absolute Error (Train): 0.00350 		Mean Absolute Error (Test): 0.00388
# At step 15200 		Mean Absolute Error (Train): 0.00156 		Mean Absolute Error (Test): 0.00085
# At step 15300 		Mean Absolute Error (Train): 0.00170 		Mean Absolute Error (Test): 0.00080
# At step 15400 		Mean Absolute Error (Train): 0.00528 		Mean Absolute Error (Test): 0.00051
# At step 15500 		Mean Absolute Error (Train): 0.00199 		Mean Absolute Error (Test): 0.00282
# At step 15600 		Mean Absolute Error (Train): 0.00478 		Mean Absolute Error (Test): 0.00513
# At step 15700 		Mean Absolute Error (Train): 0.00566 		Mean Absolute Error (Test): 0.00237
# At step 15800 		Mean Absolute Error (Train): 0.00273 		Mean Absolute Error (Test): 0.00469
# At step 15900 		Mean Absolute Error (Train): 0.00798 		Mean Absolute Error (Test): 0.00072
# At step 16000 		Mean Absolute Error (Train): 0.00191 		Mean Absolute Error (Test): 0.00818
# At step 16100 		Mean Absolute Error (Train): 0.00144 		Mean Absolute Error (Test): 0.00275
# At step 16200 		Mean Absolute Error (Train): 0.00207 		Mean Absolute Error (Test): 0.00231
# At step 16300 		Mean Absolute Error (Train): 0.00159 		Mean Absolute Error (Test): 0.00132
# At step 16400 		Mean Absolute Error (Train): 0.00165 		Mean Absolute Error (Test): 0.00444
# At step 16500 		Mean Absolute Error (Train): 0.00336 		Mean Absolute Error (Test): 0.00150
# At step 16600 		Mean Absolute Error (Train): 0.00168 		Mean Absolute Error (Test): 0.00362
# At step 16700 		Mean Absolute Error (Train): 0.00443 		Mean Absolute Error (Test): 0.00269
# At step 16800 		Mean Absolute Error (Train): 0.00374 		Mean Absolute Error (Test): 0.00431
# At step 16900 		Mean Absolute Error (Train): 0.00210 		Mean Absolute Error (Test): 0.00312
# At step 17000 		Mean Absolute Error (Train): 0.00270 		Mean Absolute Error (Test): 0.00066
# At step 17100 		Mean Absolute Error (Train): 0.00243 		Mean Absolute Error (Test): 0.00424
# At step 17200 		Mean Absolute Error (Train): 0.00414 		Mean Absolute Error (Test): 0.00074
# At step 17300 		Mean Absolute Error (Train): 0.00238 		Mean Absolute Error (Test): 0.00419
# At step 17400 		Mean Absolute Error (Train): 0.00160 		Mean Absolute Error (Test): 0.00093
# At step 17500 		Mean Absolute Error (Train): 0.00212 		Mean Absolute Error (Test): 0.00230
# At step 17600 		Mean Absolute Error (Train): 0.00495 		Mean Absolute Error (Test): 0.00995
# At step 17700 		Mean Absolute Error (Train): 0.00177 		Mean Absolute Error (Test): 0.00252
# At step 17800 		Mean Absolute Error (Train): 0.00191 		Mean Absolute Error (Test): 0.00613
# At step 17900 		Mean Absolute Error (Train): 0.00246 		Mean Absolute Error (Test): 0.00437
# At step 18000 		Mean Absolute Error (Train): 0.00213 		Mean Absolute Error (Test): 0.00093
# At step 18100 		Mean Absolute Error (Train): 0.00154 		Mean Absolute Error (Test): 0.00394
# At step 18200 		Mean Absolute Error (Train): 0.00483 		Mean Absolute Error (Test): 0.00279
# At step 18300 		Mean Absolute Error (Train): 0.00114 		Mean Absolute Error (Test): 0.00242
# At step 18400 		Mean Absolute Error (Train): 0.00516 		Mean Absolute Error (Test): 0.00235
# At step 18500 		Mean Absolute Error (Train): 0.00146 		Mean Absolute Error (Test): 0.00389
# At step 18600 		Mean Absolute Error (Train): 0.00222 		Mean Absolute Error (Test): 0.00100
# At step 18700 		Mean Absolute Error (Train): 0.00104 		Mean Absolute Error (Test): 0.00602
# At step 18800 		Mean Absolute Error (Train): 0.00094 		Mean Absolute Error (Test): 0.00239
# At step 18900 		Mean Absolute Error (Train): 0.00219 		Mean Absolute Error (Test): 0.00089
# At step 19000 		Mean Absolute Error (Train): 0.00231 		Mean Absolute Error (Test): 0.00319
# At step 19100 		Mean Absolute Error (Train): 0.00480 		Mean Absolute Error (Test): 0.00296
# At step 19200 		Mean Absolute Error (Train): 0.00164 		Mean Absolute Error (Test): 0.00269
# At step 19300 		Mean Absolute Error (Train): 0.00112 		Mean Absolute Error (Test): 0.00426
# At step 19400 		Mean Absolute Error (Train): 0.00145 		Mean Absolute Error (Test): 0.00409
# At step 19500 		Mean Absolute Error (Train): 0.00145 		Mean Absolute Error (Test): 0.00630
# At step 19600 		Mean Absolute Error (Train): 0.00140 		Mean Absolute Error (Test): 0.00251
# At step 19700 		Mean Absolute Error (Train): 0.00146 		Mean Absolute Error (Test): 0.00608
# At step 19800 		Mean Absolute Error (Train): 0.00179 		Mean Absolute Error (Test): 0.00518
# At step 19900 		Mean Absolute Error (Train): 0.00102 		Mean Absolute Error (Test): 0.00227
# At step 20000 		Mean Absolute Error (Train): 0.00147 		Mean Absolute Error (Test): 0.00201
# At step 20100 		Mean Absolute Error (Train): 0.00165 		Mean Absolute Error (Test): 0.00079
# At step 20200 		Mean Absolute Error (Train): 0.00125 		Mean Absolute Error (Test): 0.00177
# At step 20300 		Mean Absolute Error (Train): 0.00527 		Mean Absolute Error (Test): 0.00238
# At step 20400 		Mean Absolute Error (Train): 0.00200 		Mean Absolute Error (Test): 0.00515
# At step 20500 		Mean Absolute Error (Train): 0.00252 		Mean Absolute Error (Test): 0.00378
# At step 20600 		Mean Absolute Error (Train): 0.00133 		Mean Absolute Error (Test): 0.00266
# At step 20700 		Mean Absolute Error (Train): 0.00181 		Mean Absolute Error (Test): 0.00268
# At step 20800 		Mean Absolute Error (Train): 0.00203 		Mean Absolute Error (Test): 0.00505
# At step 20900 		Mean Absolute Error (Train): 0.00123 		Mean Absolute Error (Test): 0.00072
# At step 21000 		Mean Absolute Error (Train): 0.00221 		Mean Absolute Error (Test): 0.00073
# At step 21100 		Mean Absolute Error (Train): 0.00143 		Mean Absolute Error (Test): 0.00073
# At step 21200 		Mean Absolute Error (Train): 0.00108 		Mean Absolute Error (Test): 0.00431
# At step 21300 		Mean Absolute Error (Train): 0.00223 		Mean Absolute Error (Test): 0.00392
# At step 21400 		Mean Absolute Error (Train): 0.00142 		Mean Absolute Error (Test): 0.00673
# At step 21500 		Mean Absolute Error (Train): 0.00216 		Mean Absolute Error (Test): 0.00423
# At step 21600 		Mean Absolute Error (Train): 0.00190 		Mean Absolute Error (Test): 0.00142
# At step 21700 		Mean Absolute Error (Train): 0.00103 		Mean Absolute Error (Test): 0.00191
# At step 21800 		Mean Absolute Error (Train): 0.00395 		Mean Absolute Error (Test): 0.00371
# At step 21900 		Mean Absolute Error (Train): 0.00453 		Mean Absolute Error (Test): 0.00376
# At step 22000 		Mean Absolute Error (Train): 0.00206 		Mean Absolute Error (Test): 0.00313
# At step 22100 		Mean Absolute Error (Train): 0.00156 		Mean Absolute Error (Test): 0.00337
# At step 22200 		Mean Absolute Error (Train): 0.00089 		Mean Absolute Error (Test): 0.00143
# At step 22300 		Mean Absolute Error (Train): 0.00483 		Mean Absolute Error (Test): 0.00467
# At step 22400 		Mean Absolute Error (Train): 0.00416 		Mean Absolute Error (Test): 0.00337
# At step 22500 		Mean Absolute Error (Train): 0.00307 		Mean Absolute Error (Test): 0.00068
# At step 22600 		Mean Absolute Error (Train): 0.00097 		Mean Absolute Error (Test): 0.00386
# At step 22700 		Mean Absolute Error (Train): 0.00183 		Mean Absolute Error (Test): 0.00340
# At step 22800 		Mean Absolute Error (Train): 0.00154 		Mean Absolute Error (Test): 0.00314
# At step 22900 		Mean Absolute Error (Train): 0.00132 		Mean Absolute Error (Test): 0.00235
# At step 23000 		Mean Absolute Error (Train): 0.00186 		Mean Absolute Error (Test): 0.00478
# At step 23100 		Mean Absolute Error (Train): 0.00339 		Mean Absolute Error (Test): 0.00279
# At step 23200 		Mean Absolute Error (Train): 0.00206 		Mean Absolute Error (Test): 0.00452
# At step 23300 		Mean Absolute Error (Train): 0.00164 		Mean Absolute Error (Test): 0.00382
# At step 23400 		Mean Absolute Error (Train): 0.00334 		Mean Absolute Error (Test): 0.00103
# At step 23500 		Mean Absolute Error (Train): 0.00227 		Mean Absolute Error (Test): 0.00250
# At step 23600 		Mean Absolute Error (Train): 0.00174 		Mean Absolute Error (Test): 0.00270
# At step 23700 		Mean Absolute Error (Train): 0.00152 		Mean Absolute Error (Test): 0.00667
# At step 23800 		Mean Absolute Error (Train): 0.00470 		Mean Absolute Error (Test): 0.00112
# At step 23900 		Mean Absolute Error (Train): 0.00163 		Mean Absolute Error (Test): 0.00209
# At step 24000 		Mean Absolute Error (Train): 0.00146 		Mean Absolute Error (Test): 0.00186
# At step 24100 		Mean Absolute Error (Train): 0.00099 		Mean Absolute Error (Test): 0.00249
# At step 24200 		Mean Absolute Error (Train): 0.00209 		Mean Absolute Error (Test): 0.00100
# At step 24300 		Mean Absolute Error (Train): 0.00154 		Mean Absolute Error (Test): 0.00368
# At step 24400 		Mean Absolute Error (Train): 0.00134 		Mean Absolute Error (Test): 0.00338
# At step 24500 		Mean Absolute Error (Train): 0.00291 		Mean Absolute Error (Test): 0.00295
# At step 24600 		Mean Absolute Error (Train): 0.00118 		Mean Absolute Error (Test): 0.00131
# At step 24700 		Mean Absolute Error (Train): 0.00142 		Mean Absolute Error (Test): 0.00506
# At step 24800 		Mean Absolute Error (Train): 0.00173 		Mean Absolute Error (Test): 0.00513
# At step 24900 		Mean Absolute Error (Train): 0.00104 		Mean Absolute Error (Test): 0.00094
# At step 25000 		Mean Absolute Error (Train): 0.00121 		Mean Absolute Error (Test): 0.00207
# At step 25100 		Mean Absolute Error (Train): 0.00162 		Mean Absolute Error (Test): 0.00399
# At step 25200 		Mean Absolute Error (Train): 0.00168 		Mean Absolute Error (Test): 0.00108
# At step 25300 		Mean Absolute Error (Train): 0.00157 		Mean Absolute Error (Test): 0.00441
# At step 25400 		Mean Absolute Error (Train): 0.00120 		Mean Absolute Error (Test): 0.00068
# At step 25500 		Mean Absolute Error (Train): 0.00300 		Mean Absolute Error (Test): 0.00257
# At step 25600 		Mean Absolute Error (Train): 0.00223 		Mean Absolute Error (Test): 0.00418
# At step 25700 		Mean Absolute Error (Train): 0.00125 		Mean Absolute Error (Test): 0.00095
# At step 25800 		Mean Absolute Error (Train): 0.00154 		Mean Absolute Error (Test): 0.00414
# At step 25900 		Mean Absolute Error (Train): 0.00085 		Mean Absolute Error (Test): 0.00324
# At step 26000 		Mean Absolute Error (Train): 0.00132 		Mean Absolute Error (Test): 0.00290
# At step 26100 		Mean Absolute Error (Train): 0.00176 		Mean Absolute Error (Test): 0.00209
# At step 26200 		Mean Absolute Error (Train): 0.00154 		Mean Absolute Error (Test): 0.00092
# At step 26300 		Mean Absolute Error (Train): 0.00684 		Mean Absolute Error (Test): 0.00104
# At step 26400 		Mean Absolute Error (Train): 0.00147 		Mean Absolute Error (Test): 0.00083
# At step 26500 		Mean Absolute Error (Train): 0.00202 		Mean Absolute Error (Test): 0.00458
# At step 26600 		Mean Absolute Error (Train): 0.00118 		Mean Absolute Error (Test): 0.00298
# At step 26700 		Mean Absolute Error (Train): 0.00144 		Mean Absolute Error (Test): 0.00324
# At step 26800 		Mean Absolute Error (Train): 0.00168 		Mean Absolute Error (Test): 0.00220
# At step 26900 		Mean Absolute Error (Train): 0.00146 		Mean Absolute Error (Test): 0.00303
# At step 27000 		Mean Absolute Error (Train): 0.00187 		Mean Absolute Error (Test): 0.00406
# At step 27100 		Mean Absolute Error (Train): 0.00150 		Mean Absolute Error (Test): 0.00496
# At step 27200 		Mean Absolute Error (Train): 0.00121 		Mean Absolute Error (Test): 0.00314
# At step 27300 		Mean Absolute Error (Train): 0.00192 		Mean Absolute Error (Test): 0.00251
# At step 27400 		Mean Absolute Error (Train): 0.00146 		Mean Absolute Error (Test): 0.00460
# At step 27500 		Mean Absolute Error (Train): 0.00129 		Mean Absolute Error (Test): 0.00461
# At step 27600 		Mean Absolute Error (Train): 0.00122 		Mean Absolute Error (Test): 0.00109
# At step 27700 		Mean Absolute Error (Train): 0.00153 		Mean Absolute Error (Test): 0.00312
# At step 27800 		Mean Absolute Error (Train): 0.00155 		Mean Absolute Error (Test): 0.00423
# At step 27900 		Mean Absolute Error (Train): 0.00115 		Mean Absolute Error (Test): 0.00382
# At step 28000 		Mean Absolute Error (Train): 0.00159 		Mean Absolute Error (Test): 0.00118
# At step 28100 		Mean Absolute Error (Train): 0.00150 		Mean Absolute Error (Test): 0.00551
# At step 28200 		Mean Absolute Error (Train): 0.00104 		Mean Absolute Error (Test): 0.00579
# At step 28300 		Mean Absolute Error (Train): 0.00109 		Mean Absolute Error (Test): 0.00144
# At step 28400 		Mean Absolute Error (Train): 0.00114 		Mean Absolute Error (Test): 0.00330
# At step 28500 		Mean Absolute Error (Train): 0.00116 		Mean Absolute Error (Test): 0.00264
# At step 28600 		Mean Absolute Error (Train): 0.00199 		Mean Absolute Error (Test): 0.00199
# At step 28700 		Mean Absolute Error (Train): 0.00148 		Mean Absolute Error (Test): 0.00055
# At step 28800 		Mean Absolute Error (Train): 0.00140 		Mean Absolute Error (Test): 0.00213
# At step 28900 		Mean Absolute Error (Train): 0.00126 		Mean Absolute Error (Test): 0.00632
# At step 29000 		Mean Absolute Error (Train): 0.00434 		Mean Absolute Error (Test): 0.00090
# At step 29100 		Mean Absolute Error (Train): 0.00096 		Mean Absolute Error (Test): 0.00089
# At step 29200 		Mean Absolute Error (Train): 0.00114 		Mean Absolute Error (Test): 0.00376
# At step 29300 		Mean Absolute Error (Train): 0.00148 		Mean Absolute Error (Test): 0.00282
# At step 29400 		Mean Absolute Error (Train): 0.00108 		Mean Absolute Error (Test): 0.00063
# At step 29500 		Mean Absolute Error (Train): 0.00098 		Mean Absolute Error (Test): 0.00360
# At step 29600 		Mean Absolute Error (Train): 0.00131 		Mean Absolute Error (Test): 0.00530
# At step 29700 		Mean Absolute Error (Train): 0.00120 		Mean Absolute Error (Test): 0.00936
# At step 29800 		Mean Absolute Error (Train): 0.00147 		Mean Absolute Error (Test): 0.00064
# At step 29900 		Mean Absolute Error (Train): 0.00193 		Mean Absolute Error (Test): 0.00043
# At step 30000 		Mean Absolute Error (Train): 0.00137 		Mean Absolute Error (Test): 0.00402
# At step 30100 		Mean Absolute Error (Train): 0.00207 		Mean Absolute Error (Test): 0.00493
# At step 30200 		Mean Absolute Error (Train): 0.00113 		Mean Absolute Error (Test): 0.00439
# At step 30300 		Mean Absolute Error (Train): 0.00135 		Mean Absolute Error (Test): 0.00366
# At step 30400 		Mean Absolute Error (Train): 0.00128 		Mean Absolute Error (Test): 0.00041
# At step 30500 		Mean Absolute Error (Train): 0.00107 		Mean Absolute Error (Test): 0.00601
# At step 30600 		Mean Absolute Error (Train): 0.00125 		Mean Absolute Error (Test): 0.00059
# At step 30700 		Mean Absolute Error (Train): 0.00068 		Mean Absolute Error (Test): 0.00384
# At step 30800 		Mean Absolute Error (Train): 0.00095 		Mean Absolute Error (Test): 0.00121
# At step 30900 		Mean Absolute Error (Train): 0.00277 		Mean Absolute Error (Test): 0.00285
# At step 31000 		Mean Absolute Error (Train): 0.00093 		Mean Absolute Error (Test): 0.00623
# At step 31100 		Mean Absolute Error (Train): 0.00204 		Mean Absolute Error (Test): 0.00098
# At step 31200 		Mean Absolute Error (Train): 0.00142 		Mean Absolute Error (Test): 0.00547
# At step 31300 		Mean Absolute Error (Train): 0.00144 		Mean Absolute Error (Test): 0.00378
# At step 31400 		Mean Absolute Error (Train): 0.00132 		Mean Absolute Error (Test): 0.00372
# At step 31500 		Mean Absolute Error (Train): 0.00118 		Mean Absolute Error (Test): 0.00211
# At step 31600 		Mean Absolute Error (Train): 0.00152 		Mean Absolute Error (Test): 0.00043
# At step 31700 		Mean Absolute Error (Train): 0.00110 		Mean Absolute Error (Test): 0.00350
# At step 31800 		Mean Absolute Error (Train): 0.00126 		Mean Absolute Error (Test): 0.00081
# At step 31900 		Mean Absolute Error (Train): 0.00090 		Mean Absolute Error (Test): 0.00428
# At step 32000 		Mean Absolute Error (Train): 0.00131 		Mean Absolute Error (Test): 0.00294
# At step 32100 		Mean Absolute Error (Train): 0.00135 		Mean Absolute Error (Test): 0.00255
# At step 32200 		Mean Absolute Error (Train): 0.00141 		Mean Absolute Error (Test): 0.00303
# At step 32300 		Mean Absolute Error (Train): 0.00112 		Mean Absolute Error (Test): 0.00729
# At step 32400 		Mean Absolute Error (Train): 0.00119 		Mean Absolute Error (Test): 0.00609
# At step 32500 		Mean Absolute Error (Train): 0.00130 		Mean Absolute Error (Test): 0.00490
# At step 32600 		Mean Absolute Error (Train): 0.00100 		Mean Absolute Error (Test): 0.00444
# At step 32700 		Mean Absolute Error (Train): 0.00123 		Mean Absolute Error (Test): 0.00527
# At step 32800 		Mean Absolute Error (Train): 0.00144 		Mean Absolute Error (Test): 0.00178
# At step 32900 		Mean Absolute Error (Train): 0.00150 		Mean Absolute Error (Test): 0.00252
# At step 33000 		Mean Absolute Error (Train): 0.00228 		Mean Absolute Error (Test): 0.00593
# At step 33100 		Mean Absolute Error (Train): 0.00103 		Mean Absolute Error (Test): 0.00395
# At step 33200 		Mean Absolute Error (Train): 0.00109 		Mean Absolute Error (Test): 0.00213
# At step 33300 		Mean Absolute Error (Train): 0.00132 		Mean Absolute Error (Test): 0.00645
# At step 33400 		Mean Absolute Error (Train): 0.00115 		Mean Absolute Error (Test): 0.00271
# At step 33500 		Mean Absolute Error (Train): 0.00154 		Mean Absolute Error (Test): 0.00372
# At step 33600 		Mean Absolute Error (Train): 0.00132 		Mean Absolute Error (Test): 0.00415
# At step 33700 		Mean Absolute Error (Train): 0.00354 		Mean Absolute Error (Test): 0.00441
# At step 33800 		Mean Absolute Error (Train): 0.00126 		Mean Absolute Error (Test): 0.00480
# At step 33900 		Mean Absolute Error (Train): 0.00183 		Mean Absolute Error (Test): 0.00445
# At step 34000 		Mean Absolute Error (Train): 0.00123 		Mean Absolute Error (Test): 0.00121
# At step 34100 		Mean Absolute Error (Train): 0.00120 		Mean Absolute Error (Test): 0.00365
# At step 34200 		Mean Absolute Error (Train): 0.00135 		Mean Absolute Error (Test): 0.00304
# At step 34300 		Mean Absolute Error (Train): 0.00077 		Mean Absolute Error (Test): 0.00090
# At step 34400 		Mean Absolute Error (Train): 0.00143 		Mean Absolute Error (Test): 0.00366
# At step 34500 		Mean Absolute Error (Train): 0.00127 		Mean Absolute Error (Test): 0.00101
# At step 34600 		Mean Absolute Error (Train): 0.00135 		Mean Absolute Error (Test): 0.00361
# At step 34700 		Mean Absolute Error (Train): 0.00098 		Mean Absolute Error (Test): 0.00666
# At step 34800 		Mean Absolute Error (Train): 0.00147 		Mean Absolute Error (Test): 0.00545
# At step 34900 		Mean Absolute Error (Train): 0.00092 		Mean Absolute Error (Test): 0.00207
# At step 35000 		Mean Absolute Error (Train): 0.00210 		Mean Absolute Error (Test): 0.00287
# At step 35100 		Mean Absolute Error (Train): 0.00086 		Mean Absolute Error (Test): 0.00441
# At step 35200 		Mean Absolute Error (Train): 0.00079 		Mean Absolute Error (Test): 0.00074
# At step 35300 		Mean Absolute Error (Train): 0.00113 		Mean Absolute Error (Test): 0.00449
# At step 35400 		Mean Absolute Error (Train): 0.00107 		Mean Absolute Error (Test): 0.00522
# At step 35500 		Mean Absolute Error (Train): 0.00129 		Mean Absolute Error (Test): 0.00085
# At step 35600 		Mean Absolute Error (Train): 0.00150 		Mean Absolute Error (Test): 0.00407
# At step 35700 		Mean Absolute Error (Train): 0.00102 		Mean Absolute Error (Test): 0.00464
# At step 35800 		Mean Absolute Error (Train): 0.00103 		Mean Absolute Error (Test): 0.00209
# At step 35900 		Mean Absolute Error (Train): 0.00139 		Mean Absolute Error (Test): 0.00182
# At step 36000 		Mean Absolute Error (Train): 0.00099 		Mean Absolute Error (Test): 0.00381
# At step 36100 		Mean Absolute Error (Train): 0.00134 		Mean Absolute Error (Test): 0.00595
# At step 36200 		Mean Absolute Error (Train): 0.00108 		Mean Absolute Error (Test): 0.00238
# At step 36300 		Mean Absolute Error (Train): 0.00131 		Mean Absolute Error (Test): 0.00649
# At step 36400 		Mean Absolute Error (Train): 0.00108 		Mean Absolute Error (Test): 0.00414
# At step 36500 		Mean Absolute Error (Train): 0.00113 		Mean Absolute Error (Test): 0.00623
# At step 36600 		Mean Absolute Error (Train): 0.00131 		Mean Absolute Error (Test): 0.00665
# At step 36700 		Mean Absolute Error (Train): 0.00582 		Mean Absolute Error (Test): 0.00030
# At step 36800 		Mean Absolute Error (Train): 0.00141 		Mean Absolute Error (Test): 0.00243
# At step 36900 		Mean Absolute Error (Train): 0.00093 		Mean Absolute Error (Test): 0.00209
# At step 37000 		Mean Absolute Error (Train): 0.00105 		Mean Absolute Error (Test): 0.00812
# At step 37100 		Mean Absolute Error (Train): 0.00106 		Mean Absolute Error (Test): 0.00356
# At step 37200 		Mean Absolute Error (Train): 0.00075 		Mean Absolute Error (Test): 0.00149
# At step 37300 		Mean Absolute Error (Train): 0.00198 		Mean Absolute Error (Test): 0.00270
# At step 37400 		Mean Absolute Error (Train): 0.00079 		Mean Absolute Error (Test): 0.00163
# At step 37500 		Mean Absolute Error (Train): 0.00105 		Mean Absolute Error (Test): 0.00246
# At step 37600 		Mean Absolute Error (Train): 0.00128 		Mean Absolute Error (Test): 0.00140
# At step 37700 		Mean Absolute Error (Train): 0.00116 		Mean Absolute Error (Test): 0.00174
# At step 37800 		Mean Absolute Error (Train): 0.00091 		Mean Absolute Error (Test): 0.00214
# At step 37900 		Mean Absolute Error (Train): 0.00144 		Mean Absolute Error (Test): 0.00157
# At step 38000 		Mean Absolute Error (Train): 0.00089 		Mean Absolute Error (Test): 0.00382
# At step 38100 		Mean Absolute Error (Train): 0.00104 		Mean Absolute Error (Test): 0.00509
# At step 38200 		Mean Absolute Error (Train): 0.00192 		Mean Absolute Error (Test): 0.00134
# At step 38300 		Mean Absolute Error (Train): 0.00091 		Mean Absolute Error (Test): 0.00643
# At step 38400 		Mean Absolute Error (Train): 0.00096 		Mean Absolute Error (Test): 0.00384
# At step 38500 		Mean Absolute Error (Train): 0.00106 		Mean Absolute Error (Test): 0.00603
# At step 38600 		Mean Absolute Error (Train): 0.00097 		Mean Absolute Error (Test): 0.00134
# At step 38700 		Mean Absolute Error (Train): 0.00123 		Mean Absolute Error (Test): 0.00302
# At step 38800 		Mean Absolute Error (Train): 0.00099 		Mean Absolute Error (Test): 0.00068
# At step 38900 		Mean Absolute Error (Train): 0.00108 		Mean Absolute Error (Test): 0.00645
# At step 39000 		Mean Absolute Error (Train): 0.00098 		Mean Absolute Error (Test): 0.00425
# At step 39100 		Mean Absolute Error (Train): 0.00108 		Mean Absolute Error (Test): 0.00084
# At step 39200 		Mean Absolute Error (Train): 0.00140 		Mean Absolute Error (Test): 0.00325
# At step 39300 		Mean Absolute Error (Train): 0.00087 		Mean Absolute Error (Test): 0.00648
# At step 39400 		Mean Absolute Error (Train): 0.00187 		Mean Absolute Error (Test): 0.00595
# At step 39500 		Mean Absolute Error (Train): 0.00097 		Mean Absolute Error (Test): 0.00558
# At step 39600 		Mean Absolute Error (Train): 0.00350 		Mean Absolute Error (Test): 0.00178
# At step 39700 		Mean Absolute Error (Train): 0.00109 		Mean Absolute Error (Test): 0.00283
# At step 39800 		Mean Absolute Error (Train): 0.00152 		Mean Absolute Error (Test): 0.00117
# At step 39900 		Mean Absolute Error (Train): 0.00084 		Mean Absolute Error (Test): 0.00137

# %% [markdown]
# # Visualizing and testing the model

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
with tf.Session() as sess:
    #Restoring the model
    saver.restore(sess, "Pollution_model/model")
    #Preparing batches
    x_rnn_batch,x_dnn_batch,y_batch = next_batch(test_set_rnn,test_set_dnn,steps=STEPS)
    #Predicting the output
    output = sess.run(network_op, feed_dict={x_rnn:x_rnn_batch,x_dnn:x_dnn_batch, hold_proba:1.0})
# Out:
# INFO:tensorflow:Restoring parameters from Pollution_model/model

# %%
#Inverse scaling the predicted and actual values
y_inversed = pol_scaler.inverse_transform(y_batch).reshape(-1,1)
pred_inversed = pol_scaler.inverse_transform(output).reshape(-1,1)
dataframe = np.append(y_inversed,pred_inversed,1)

# %%
##Creating the dataframe
df = pd.DataFrame(dataframe,columns=['Actual','Prediction'])
#Plotting the graph
df.plot(figsize=(15,6))
plt.title("Actual Data vs Prediction Data (Test Dataset)")
plt.ylabel("Pollution")
plt.xlabel('Timestep')
plt.show()
#Calculating MAE and RMSE error
y_true = df['Actual'].values
y_pred = df['Prediction'].values
score_mae = mean_absolute_error(y_true,y_pred)
score_mse = mean_squared_error(y_true,y_pred)
print("Mean Absolute Error (Test)\t=\t",score_mae)
print("Root Mean Squared Error (Test)\t=\t",score_mse**0.5)
print("Per cent Error (Test)\t=\t",score_mae*100/df['Actual'].max())
# Out:
# Mean Absolute Error (Test)	=	 35.38118705749512
# Root Mean Squared Error (Test)	=	 45.87133386299176
# Per cent Error (Test)	=	 11.056620955467224

# %%
#Converting dataset to spreadsheet
df.to_csv('prediction.csv')

# %% [markdown]
# # Predicting Future data

# %%
forecast=15
seed=30

# %%
with tf.Session() as sess:
    
    # Restoring the model
    saver.restore(sess, "Pollution_model/model")

    #Creating the Seed of 1 Week's data
    train_seed_rnn = list(training_set_rnn[-seed-PRED_DIST:-PRED_DIST])
    train_seed_dnn = list(training_set_dnn[-seed-PRED_DIST:-PRED_DIST])
    test_ind = 0
    #Predicting the next week's data
    for iteration in range(forecast):
        rnn_batch = np.array(train_seed_rnn[-forecast:]).reshape(-1,forecast, 1)
        dnn_batch = np.array(train_seed_dnn[-forecast:]).reshape(-1,20)
        y_pred = sess.run(network_op, feed_dict={x_rnn:rnn_batch,x_dnn:dnn_batch, hold_proba:1.0})
        #print("\nPrediction: ",y_pred[0, -1])
        train_seed_rnn.append(y_pred[-1])
        #print("Feed_data: ",test_set_dnn[test_ind])
        train_seed_dnn.append(test_set_dnn[test_ind])
        test_ind+=1
# Out:
# INFO:tensorflow:Restoring parameters from Pollution_model/model

# %%
#Inverse scaling the value
seed_data = pol_scaler.inverse_transform(training_set_rnn[-seed-PRED_DIST:-PRED_DIST])
prediction_data = pol_scaler.inverse_transform(np.array(train_seed_rnn[-forecast:]))
actual_data =  pol_scaler.inverse_transform(test_set_rnn[:forecast])
pd.DataFrame(list(seed_data[-seed:]),columns=['Seed data']).plot(c='Red')
# plt.ylim((0,350))
plt.title("Seed Data ({} days)".format(seed))
plt.show()
df = pd.DataFrame({'Actual':actual_data[:-1].reshape(1,-1)[0], 'Prediction' :prediction_data[1:].reshape(1,-1)[0]})
df.plot.bar(figsize=(15,6))
# plt.ylim((0,350))
plt.title("Actual vs Predicted (next {} days)".format(forecast-1))
plt.show()
y_pred = df['Prediction'].values
y_true = df['Actual'].values
score_mae = mean_absolute_error(y_true,y_pred)
print(score_mae)
print("Error ratio (Test):\t%1.2f"%((score_mae/df['Actual'].max())*100),"%")
# Out:
# 23.282412392752512
# Error ratio (Test):	4.30 %
